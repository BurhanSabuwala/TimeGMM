# %%
import numpy as np
import pandas as pd
import GMM
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.random.normal(size = 1000)
y = 6*np.random.normal(size = 1000)

# %%
data = np.array([x,y]).reshape(1000,2)

# %%
model = GMM.initialize(data, 2, case = "diag")

# %%
model
# Out:
# {0: {'w': 0.818,
#   'mu': array([[ 0.83773021],
#          [-0.92636286]]),
#   'cov': array([[12.08800135,  0.        ],
#          [ 0.        , 10.23137819]])},
#  1: {'w': 0.182,
#   'mu': array([[-3.45269262],
#          [ 4.96751774]]),
#   'cov': array([[26.02087395,  0.        ],
#          [ 0.        , 16.74841469]])}}

# %%
model = GMM.gmm(data, 4, case= "diag")

# %%
GMM.contour_plot_3d(model, [(-6,6), [-6,6]])
